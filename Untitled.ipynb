# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from artificial_gps.experiment1 import train_static_model
from artificial_gps.utils import save_model_with_scalers_binary
from artificial_gps.nn_tuned_training import train_tuned_model
from artificial_gps.model_tester import test_model_predictions, test_lstm_model_predictions
from artificial_gps.lstm_experiment import train_lstm_model
from artificial_gps.lstm_tuned_training import train_save_tuned_lstm_model, get_best_model

from artificial_gps.settings import (
    INPUT_DATA_COLUMNS,
    OUTPUT_DATA_COLUMNS,
    INPUT_SEQUENCE_COLUMNS,
    OUTPUT_SEQUENCE_COLUMNS,
    INPUT_SEQUENCE_LENGTH
)

if __name__ == "__main__":
    trained_on = ["flight_2021:12:21_20:52:19_1_record.csv",
                  "flight_2021:12:21_20:05:53_1_record.csv",
                  "flight_2021:12:26_21:37:31_1_record.csv"]
    new_data = ["flight_2021:12:21_19:38:37_1_record.csv", "flight_2021:12:28_00:25:05_1_record.csv"]
    predicted_offset, real_offset, time_offset =  test_model_predictions("without_velocity_1",
                                trained_on[0],
                                INPUT_DATA_COLUMNS,
                                OUTPUT_DATA_COLUMNS)
    
    #     predicted_offset, real_offset, time_offset =     test_lstm_model_predictions("LSTM_after_hahaaaa",
#                                 trained_on[1],
#                                 INPUT_SEQUENCE_COLUMNS,
#                                 OUTPUT_SEQUENCE_COLUMNS,
#                                 INPUT_SEQUENCE_LENGTH)
# Out:
# position:
# real offset:      [ 0.          0.         -0.00125684]
# predicted offset: [-0.06506945 -0.16411714  0.02005713]
# time offset(seconds): [0.01500032]
#
#
# position:
# real offset:      [0.         0.         2.76904911]
# predicted offset: [ 0.5976729 -4.9246464  3.8725421]
# time offset(seconds): [1.00202138]
#
#
# position:
# real offset:      [0.         0.         8.94472975]
# predicted offset: [  1.5640572 -10.377783    9.199747 ]
# time offset(seconds): [2.00404275]
#
#
# position:
# real offset:      [ 0.          0.         15.94867128]
# predicted offset: [  2.5728264 -16.01513    15.029545 ]
# time offset(seconds): [3.01206426]
#
#
# position:
# real offset:      [ 0.          0.         23.01463884]
# predicted offset: [  3.4563878 -21.570663   20.896212 ]
# time offset(seconds): [4.01108557]
#
#
# position:
# real offset:      [ 0.          0.         30.07519716]
# predicted offset: [  4.241555 -27.008179  26.712564]
# time offset(seconds): [5.00710682]
#
#
# position:
# real offset:      [ 0.          0.         37.15640634]
# predicted offset: [  4.843829 -32.30034   32.49349 ]
# time offset(seconds): [6.00612813]
#
#
# position:
# real offset:      [ 0.          0.         44.25573725]
# predicted offset: [  5.339322 -37.448     38.216286]
# time offset(seconds): [7.0081495]
#
#
# position:
# real offset:      [ 0.         0.        51.3302955]
# predicted offset: [  5.7086763 -42.44219    43.884087 ]
# time offset(seconds): [8.00717082]
#
#
# position:
# real offset:      [ 0.         0.        58.4225654]
# predicted offset: [  6.011205 -47.33169   49.505264]
# time offset(seconds): [9.00919219]
#
#
# position:
# real offset:      [  0.           0.         100.77367014]
# predicted offset: [  6.186823 -72.9166    81.655655]
# time offset(seconds): [15.00332006]
#
#
# position:
# real offset:      [  5.55236673   1.446365   133.33824533]
# predicted offset: [  8.416635 -86.2896   105.32207 ]
# time offset(seconds): [20.01042688]
#
#
# position:
# real offset:      [ 89.36174774   5.81929827 126.66764444]
# predicted offset: [ 49.563847 -90.51988  130.80351 ]
# time offset(seconds): [25.01753344]
#
#
# position:
# real offset:      [129.79554749   9.89395142 136.57272714]
# predicted offset: [ 62.563496 -93.57236  134.96848 ]
# time offset(seconds): [30.01264026]
#
#
# position:
# real offset:      [ 89.39408875  13.73513794 121.1832847 ]
# predicted offset: [  58.201633 -108.48379   134.9897  ]
# time offset(seconds): [40.00285338]
#
#
# position:
# real offset:      [ 39.49768829 -25.35392952 103.38750833]
# predicted offset: [  -3.8017642 -141.98479    144.41824  ]
# time offset(seconds): [50.00206669]
#
#
# position:
# real offset:      [  2.19856215 126.70998383 108.8332786 ]
# predicted offset: [ -71.37959 -197.00479  212.77486]
# time offset(seconds): [100.00413338]

# %%
plt.plot(predicted_offset[:,0])
plt.plot(real_offset[:, 0])

# %%
plt.plot(predicted_offset[:,1])
plt.plot(real_offset[:, 1])

# %%
plt.plot(predicted_offset[:,2])
plt.plot(real_offset[:, 2])

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>
